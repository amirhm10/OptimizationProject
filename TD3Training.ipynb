# %% [markdown]
# ## Importing libraries and PFR geometry

# %%
import numpy as np
import math
from PDESystems.pfr_pde import PfrIpoptEnv
import torch
from Encoders.pca_model import PcaWarmLibrary
from Encoders.autoencoder import AeWarmLibrary, PrimalsAutoencoder
from Encoders.variational_autoncoder import VaeWarmLibrary, PrimalsVAE
from Encoders.regressor_train import LatentRegressor
from TD3Agent.agent import TD3Agent
from rl_helper.train_fn import run_td3_with_baseline

# %%
# Device
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
D_tube = 0.126
A_t = math.pi * (D_tube / 2.0) ** 2

params = {
    # geometry
    "A_t":   A_t,

    # inlet
    "cA_in": 80.0,
    "cB_in": 0.0,
    "cC_in": 0.0,
    "T_in": 423.0,

    # kinetics
    "Rgas": 8.314,
    "k01": 0.1, # 1/h
    "E1": 33475.0, # J/mol
    "k02": 9.0e-7, # m^3/(mol*h)
    "E2": 75319.0, # J/mol

    # heats of reaction (exothermic)
    "dH1": -20.0e3, # J/mol
    "dH2": -60.0e3, # J/mol

    # heat transfer per volume + volumetric heat capacity
    "Ua": 8524.0 * 1e3, # J/(m^3*h*K)
    "rhoCp": 8.0e5, # J/(m^3*K)

    # MV bounds
    "F_min": 0.6,
    "F_max": 4.5,
    "Tj_min": 298.0,
    "Tj_max": 600.0,

    # path/safety bounds on Tr
    "T_lo": 280.0,
    "T_hi": 700.0,
}

# %%
# Coarse mesh
pca_env = PfrIpoptEnv(
    params=params,
    N=10,
    K=20,
    L=20.0,
    dt=0.02,
    target_species="B",
    n_zones=5,
    max_iter=500,
)

# %%
# setpoints generation
num_episodes = 3000
np.random.seed(42)
setpoints = np.random.uniform(20.0, 55.0, size=num_episodes)

# %% [markdown]
# # TD3 and Reward Config

# %%
STATE_DIM = 19
ACTION_DIM = 5  # [a_warm, a_pca, a_mu, a_tol, a_atol]
ACTOR_LAYER_SIZES = [256, 256, 256, 256]
CRITIC_LAYER_SIZES = [256, 256, 256, 256]
BUFFER_CAPACITY = 200_000
ACTOR_LR = 1e-4
CRITIC_LR = 1e-4
SMOOTHING_STD = 0.2
NOISE_CLIP = 0.5
GAMMA = 0.99
TAU = 0.01
MAX_ACTION = 1.0
POLICY_DELAY = 2
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
BATCH_SIZE = 128
STD_START = 0.2
STD_END = 0.01
STD_DECAY_RATE = 0.99995
STD_DECAY_MODE = "exp"

# %%
REWARD_CFG = {
    # feasibility / reliability
    "R_fail_vs_base": 500.0, # baseline solves, RL fails
    "R_rescue": 500.0, # baseline fails, RL solves
    "R_both_fail": 50.0, # both fail

    # efficiency weights
    "w_iter": 50.0, # weight on iteration gain
    "w_time": 10.0, # weight on time gain

    # solution quality (tracking/objective) weight
    "w_L": 1.0,

    # safety (temperature margin) weight
    "w_Tsafe": 1.0,

    # KKT-ish weight (multipliers/active bounds)
    "w_kkt": 0.5,

    # action regularization
    "w_act": 1e-3,   # penalty on |a|^2
    "w_act_delta": 1e-3, # penalty on |a_k - a_{k-1}|^2
}

# %%
def make_td3_agent():
    return TD3Agent(
        state_dim=STATE_DIM,
        action_dim=ACTION_DIM,
        actor_hidden=ACTOR_LAYER_SIZES,
        critic_hidden=CRITIC_LAYER_SIZES,
        gamma=GAMMA,
        actor_lr=ACTOR_LR,
        critic_lr=CRITIC_LR,
        batch_size=BATCH_SIZE,
        policy_delay=POLICY_DELAY,
        target_policy_smoothing_noise_std=SMOOTHING_STD,
        noise_clip=NOISE_CLIP,
        max_action=MAX_ACTION,
        tau=TAU,
        std_start=STD_START,
        std_end=STD_END,
        std_decay_rate=STD_DECAY_RATE,
        std_decay_mode=STD_DECAY_MODE,
        buffer_size=BUFFER_CAPACITY,
        device=DEVICE,
        actor_freeze=0,
        mode="mpc",
    )

# %% [markdown]
# ## Without optimal primal solution

# %%
td3_agent = make_td3_agent()

# %%
env_rl = PfrIpoptEnv(
    params=params,
    N=10,
    K=20,
    L=20.0,
    dt=0.02,
    target_species="B",
    n_zones=5,
    max_iter=500,
    pca_lib=None,
)

env_base = PfrIpoptEnv(
    params=params,
    N=10,
    K=20,
    L=20.0,
    dt=0.02,
    target_species="B",
    n_zones=5,
    max_iter=500,
    pca_lib=None,
)

stats = run_td3_with_baseline(
    env_rl=env_rl,
    env_base=env_base,
    agent=td3_agent,
    setpoints=setpoints,
    warm_start_steps=100,
    cfg=REWARD_CFG,
    tee=False,
)
# Out:
# Initial setpoint s0=33.11 solved; starting RL stream with baseline...
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.19\x3a Maximum Number of Iterations
#       Exceeded.
# [PFR ENV] IPOPT failed or returned non-optimal status at s=32.49
# [step 100/2999] s=21.10, r=0.3, iters_rl=23, iters_base=23, time_rl=0.284s, time_base=0.294s | w_warm=0.39, w_pca=0.00, mu=1.85e-03, tol=5.6e-07
# [step 200/2999] s=42.47, r=40.9, iters_rl=7, iters_base=25, time_rl=0.142s, time_base=0.277s | w_warm=0.95, w_pca=0.00, mu=6.40e-04, tol=7.9e-06
# [step 300/2999] s=21.81, r=8.8, iters_rl=15, iters_base=18, time_rl=0.174s, time_base=0.182s | w_warm=1.00, w_pca=0.00, mu=1.00e-04, tol=6.6e-05
# [step 400/2999] s=23.61, r=34.9, iters_rl=18, iters_base=47, time_rl=0.282s, time_base=0.478s | w_warm=1.00, w_pca=0.00, mu=1.00e-04, tol=1.0e-04
# [step 500/2999] s=44.44, r=35.4, iters_rl=13, iters_base=32, time_rl=0.159s, time_base=0.375s | w_warm=0.93, w_pca=0.00, mu=1.86e-04, tol=1.0e-04
# [step 600/2999] s=25.91, r=2.1, iters_rl=15, iters_base=16, time_rl=0.171s, time_base=0.155s | w_warm=0.83, w_pca=0.00, mu=1.00e-04, tol=1.0e-04
# [step 700/2999] s=38.64, r=16.4, iters_rl=20, iters_base=30, time_rl=0.280s, time_base=0.274s | w_warm=0.93, w_pca=0.00, mu=1.66e-04, tol=1.0e-04
# [step 800/2999] s=44.75, r=-0.6, iters_rl=30, iters_base=30, time_rl=0.378s, time_base=0.374s | w_warm=0.88, w_pca=0.00, mu=4.17e-02, tol=1.0e-04
# [step 900/2999] s=27.28, r=-149.7, iters_rl=48, iters_base=14, time_rl=0.586s, time_base=0.155s | w_warm=0.86, w_pca=0.00, mu=8.33e-02, tol=1.0e-04
# [step 1000/2999] s=26.48, r=18.7, iters_rl=22, iters_base=33, time_rl=0.280s, time_base=0.377s | w_warm=0.98, w_pca=0.00, mu=1.00e-01, tol=1.0e-04
# [step 1100/2999] s=22.02, r=-38.8, iters_rl=53, iters_base=31, time_rl=0.483s, time_base=0.377s | w_warm=1.00, w_pca=0.00, mu=1.00e-01, tol=1.0e-04
# [step 1200/2999] s=46.54, r=-124.6, iters_rl=119, iters_base=39, time_rl=0.883s, time_base=0.275s | w_warm=0.00, w_pca=0.00, mu=1.00e-04, tol=1.0e-04
# [step 1300/2999] s=21.11, r=35.0, iters_rl=19, iters_base=45, time_rl=0.185s, time_base=0.479s | w_warm=0.82, w_pca=0.00, mu=1.00e-04, tol=1.0e-04
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.19\x3a Maximum Number of Iterations
#       Exceeded.
# [PFR ENV] IPOPT failed or returned non-optimal status at s=35.88
# [step 1400/2999] s=25.85, r=35.2, iters_rl=16, iters_base=40, time_rl=0.179s, time_base=0.375s | w_warm=1.00, w_pca=0.00, mu=1.00e-04, tol=2.4e-05
# [step 1500/2999] s=38.17, r=14.7, iters_rl=31, iters_base=41, time_rl=0.280s, time_base=0.374s | w_warm=0.95, w_pca=0.00, mu=1.46e-04, tol=1.0e-08
# [step 1600/2999] s=26.72, r=19.7, iters_rl=40, iters_base=58, time_rl=0.280s, time_base=0.478s | w_warm=0.85, w_pca=0.00, mu=1.00e-04, tol=2.0e-08
# [step 1700/2999] s=53.80, r=17.7, iters_rl=20, iters_base=28, time_rl=0.180s, time_base=0.273s | w_warm=1.00, w_pca=0.00, mu=2.10e-04, tol=1.0e-04
# [IPOPT] solve failed with ValueError: Cannot load a SolverResults object with bad status: error
# [PFR ENV] IPOPT failed or returned non-optimal status at s=24.98
# [step 1800/2999] s=53.48, r=22.3, iters_rl=26, iters_base=43, time_rl=0.279s, time_base=0.375s | w_warm=1.00, w_pca=0.00, mu=1.00e-04, tol=5.5e-05
# [step 1900/2999] s=39.40, r=15.9, iters_rl=21, iters_base=31, time_rl=0.282s, time_base=0.275s | w_warm=0.92, w_pca=0.00, mu=1.00e-04, tol=5.9e-05
# [step 2000/2999] s=29.16, r=16.8, iters_rl=17, iters_base=23, time_rl=0.171s, time_base=0.275s | w_warm=0.97, w_pca=0.00, mu=1.91e-04, tol=6.2e-05
# [step 2100/2999] s=52.03, r=27.0, iters_rl=19, iters_base=37, time_rl=0.189s, time_base=0.275s | w_warm=1.00, w_pca=0.00, mu=1.00e-04, tol=1.0e-04
# [step 2200/2999] s=54.19, r=14.5, iters_rl=22, iters_base=31, time_rl=0.279s, time_base=0.279s | w_warm=1.00, w_pca=0.00, mu=1.65e-04, tol=9.2e-05
# [step 2300/2999] s=48.09, r=26.5, iters_rl=17, iters_base=31, time_rl=0.167s, time_base=0.274s | w_warm=0.95, w_pca=0.00, mu=1.15e-04, tol=6.4e-05
# [step 2400/2999] s=31.92, r=40.5, iters_rl=11, iters_base=36, time_rl=0.158s, time_base=0.377s | w_warm=1.00, w_pca=0.00, mu=1.00e-04, tol=1.0e-04
# [step 2500/2999] s=48.96, r=23.3, iters_rl=19, iters_base=31, time_rl=0.170s, time_base=0.279s | w_warm=0.87, w_pca=0.00, mu=1.00e-04, tol=1.0e-04
# [step 2600/2999] s=42.03, r=25.0, iters_rl=18, iters_base=31, time_rl=0.166s, time_base=0.277s | w_warm=0.93, w_pca=0.00, mu=1.00e-04, tol=7.7e-05
# [step 2700/2999] s=38.25, r=33.9, iters_rl=11, iters_base=27, time_rl=0.157s, time_base=0.272s | w_warm=0.89, w_pca=0.00, mu=1.00e-04, tol=1.0e-04
# [step 2800/2999] s=47.74, r=-2.8, iters_rl=39, iters_base=37, time_rl=0.281s, time_base=0.278s | w_warm=0.18, w_pca=0.00, mu=1.39e-04, tol=8.4e-05
# [step 2900/2999] s=24.48, r=11.5, iters_rl=14, iters_base=18, time_rl=0.157s, time_base=0.164s | w_warm=0.80, w_pca=0.00, mu=1.23e-04, tol=1.0e-04
# [step 2999/2999] s=50.50, r=14.9, iters_rl=23, iters_base=33, time_rl=0.283s, time_base=0.275s | w_warm=0.43, w_pca=0.00, mu=1.00e-04, tol=1.0e-04
#
# Streaming training with baseline finished. Total RL steps = 2999

# %%
# Saving
td3_agent.save("checkpoints", prefix="td3_no_optimal")
# Out:
# Saved checkpoint to: checkpoints\td3_no_optimal_20251202_023254.pkl

# %% [markdown]
# ## Using PCA

# %%
# 1) Load library (PCA + scalers + Z_data)
pca_lib = PcaWarmLibrary.load(r"checkpoints\pca_warm_lib.joblib", coarse_env=pca_env)

# 2) Rebuild regressor with same dims
in_dim = pca_lib.feats.shape[1]
out_dim = pca_lib.Z_latent.shape[1]

pca_reg = LatentRegressor(in_dim=in_dim, out_dim=out_dim, hidden_dims=(64, 64))
state_dict = torch.load(r"checkpoints\pca_latent_regressor.pth", map_location=device)
pca_reg.load_state_dict(state_dict)
pca_reg.to(device).eval()

# 3) Attach regressor to library
pca_lib.attach_regressor(pca_reg, device=device)

# %%
td3_agent = make_td3_agent()

# %%
env_rl = PfrIpoptEnv(
    params=params,
    N=10,
    K=20,
    L=20.0,
    dt=0.02,
    target_species="B",
    n_zones=5,
    max_iter=500,
    pca_lib=pca_lib,
)

env_base = PfrIpoptEnv(
    params=params,
    N=10,
    K=20,
    L=20.0,
    dt=0.02,
    target_species="B",
    n_zones=5,
    max_iter=500,
    pca_lib=None,
)

stats = run_td3_with_baseline(
    env_rl=env_rl,
    env_base=env_base,
    agent=td3_agent,
    setpoints=setpoints,
    warm_start_steps=100,
    cfg=REWARD_CFG,
    tee=False,
)
# Out:
# Initial setpoint s0=33.11 solved; starting RL stream with baseline...
# [step 100/2999] s=21.10, r=25.9, iters_rl=13, iters_base=23, time_rl=0.161s, time_base=0.275s | w_warm=0.35, w_pca=0.31, mu=2.62e-03, tol=2.5e-06
# [step 200/2999] s=42.47, r=39.0, iters_rl=8, iters_base=25, time_rl=0.141s, time_base=0.281s | w_warm=0.66, w_pca=0.10, mu=1.34e-04, tol=3.4e-05
# [step 300/2999] s=21.81, r=24.0, iters_rl=10, iters_base=18, time_rl=0.143s, time_base=0.174s | w_warm=0.63, w_pca=0.10, mu=1.62e-04, tol=4.8e-05
# [step 400/2999] s=23.61, r=40.2, iters_rl=15, iters_base=47, time_rl=0.181s, time_base=0.477s | w_warm=0.55, w_pca=0.12, mu=1.00e-04, tol=1.0e-04
# [step 500/2999] s=44.44, r=37.0, iters_rl=12, iters_base=32, time_rl=0.161s, time_base=0.381s | w_warm=0.64, w_pca=0.10, mu=1.00e-04, tol=8.7e-05
# [step 600/2999] s=25.91, r=16.3, iters_rl=11, iters_base=16, time_rl=0.151s, time_base=0.161s | w_warm=0.42, w_pca=0.42, mu=1.52e-04, tol=3.9e-05
# [step 700/2999] s=38.64, r=39.9, iters_rl=9, iters_base=30, time_rl=0.139s, time_base=0.273s | w_warm=0.10, w_pca=0.64, mu=1.85e-04, tol=4.2e-05
# [step 800/2999] s=44.75, r=37.9, iters_rl=10, iters_base=30, time_rl=0.152s, time_base=0.279s | w_warm=0.10, w_pca=0.66, mu=2.17e-04, tol=7.8e-05
# [step 900/2999] s=27.28, r=21.9, iters_rl=8, iters_base=14, time_rl=0.147s, time_base=0.154s | w_warm=0.12, w_pca=0.62, mu=1.70e-04, tol=5.5e-05
# [step 1000/2999] s=26.48, r=42.6, iters_rl=9, iters_base=33, time_rl=0.139s, time_base=0.374s | w_warm=0.11, w_pca=0.60, mu=1.00e-04, tol=1.0e-04
# [step 1100/2999] s=22.02, r=42.0, iters_rl=9, iters_base=31, time_rl=0.131s, time_base=0.378s | w_warm=0.09, w_pca=0.67, mu=1.00e-04, tol=1.0e-04
# [step 1200/2999] s=46.54, r=36.4, iters_rl=14, iters_base=39, time_rl=0.158s, time_base=0.278s | w_warm=0.11, w_pca=0.63, mu=1.00e-04, tol=1.0e-04
# [step 1300/2999] s=21.11, r=39.7, iters_rl=15, iters_base=45, time_rl=0.171s, time_base=0.473s | w_warm=0.09, w_pca=0.66, mu=2.09e-04, tol=1.0e-04
# [step 1400/2999] s=25.85, r=42.2, iters_rl=11, iters_base=40, time_rl=0.150s, time_base=0.376s | w_warm=0.11, w_pca=0.61, mu=1.00e-04, tol=1.0e-04
# [step 1500/2999] s=38.17, r=43.7, iters_rl=10, iters_base=41, time_rl=0.153s, time_base=0.372s | w_warm=0.09, w_pca=0.67, mu=1.12e-04, tol=3.4e-05
# [step 1600/2999] s=26.72, r=45.8, iters_rl=13, iters_base=58, time_rl=0.173s, time_base=0.579s | w_warm=0.11, w_pca=0.64, mu=1.00e-04, tol=1.0e-04
# [step 1700/2999] s=53.80, r=29.5, iters_rl=14, iters_base=28, time_rl=0.152s, time_base=0.275s | w_warm=0.10, w_pca=0.63, mu=1.65e-04, tol=6.6e-05
# [step 1800/2999] s=53.48, r=30.5, iters_rl=19, iters_base=43, time_rl=0.277s, time_base=0.377s | w_warm=0.09, w_pca=0.66, mu=2.64e-04, tol=1.0e-04
# [step 1900/2999] s=39.40, r=40.3, iters_rl=9, iters_base=31, time_rl=0.141s, time_base=0.274s | w_warm=0.10, w_pca=0.64, mu=1.00e-04, tol=5.7e-05
# [step 2000/2999] s=29.16, r=10.9, iters_rl=18, iters_base=23, time_rl=0.281s, time_base=0.284s | w_warm=0.10, w_pca=0.64, mu=2.24e-04, tol=1.0e-04
# [step 2100/2999] s=52.03, r=30.9, iters_rl=17, iters_base=37, time_rl=0.170s, time_base=0.275s | w_warm=0.09, w_pca=0.67, mu=2.09e-04, tol=5.9e-05
# [step 2200/2999] s=54.19, r=14.4, iters_rl=22, iters_base=31, time_rl=0.280s, time_base=0.277s | w_warm=0.09, w_pca=0.67, mu=1.00e-04, tol=1.0e-04
# [step 2300/2999] s=48.09, r=35.3, iters_rl=12, iters_base=31, time_rl=0.149s, time_base=0.276s | w_warm=0.09, w_pca=0.67, mu=1.00e-04, tol=1.0e-04
# [step 2400/2999] s=31.92, r=43.6, iters_rl=9, iters_base=36, time_rl=0.147s, time_base=0.374s | w_warm=0.09, w_pca=0.67, mu=1.00e-04, tol=7.3e-05
# [step 2500/2999] s=48.96, r=36.8, iters_rl=11, iters_base=31, time_rl=0.150s, time_base=0.274s | w_warm=0.10, w_pca=0.64, mu=1.18e-04, tol=1.0e-04
# [step 2600/2999] s=42.03, r=33.6, iters_rl=13, iters_base=31, time_rl=0.149s, time_base=0.274s | w_warm=0.10, w_pca=0.63, mu=1.01e-04, tol=1.0e-04
# [step 2700/2999] s=38.25, r=36.1, iters_rl=10, iters_base=27, time_rl=0.147s, time_base=0.273s | w_warm=0.12, w_pca=0.65, mu=1.00e-04, tol=2.5e-05
# [step 2800/2999] s=47.74, r=37.1, iters_rl=13, iters_base=37, time_rl=0.147s, time_base=0.274s | w_warm=0.09, w_pca=0.67, mu=1.00e-04, tol=1.0e-04
# [step 2900/2999] s=24.48, r=32.0, iters_rl=7, iters_base=18, time_rl=0.143s, time_base=0.168s | w_warm=0.11, w_pca=0.64, mu=1.00e-04, tol=9.6e-05
# [step 2999/2999] s=50.50, r=31.5, iters_rl=15, iters_base=33, time_rl=0.159s, time_base=0.275s | w_warm=0.09, w_pca=0.67, mu=1.00e-04, tol=2.9e-05
#
# Streaming training with baseline finished. Total RL steps = 2999

# %%
# Saving
td3_agent.save("checkpoints", prefix="td3_pca")
# Out:
# Saved checkpoint to: checkpoints\td3_pca_20251202_025844.pkl

# %% [markdown]
# ## Using AE

# %%
# 1) load library
ae_lib = AeWarmLibrary.load(r"checkpoints\ae_warm_lib.joblib", coarse_env=pca_env)

# 2) rebuild AE model with same sizes
input_dim = ae_lib.scaler.mean_.shape[0]     # D (number of primals)
latent_dim = ae_lib.Z_latent.shape[1]        # r (latent dimension)

ae_model = PrimalsAutoencoder(input_dim=input_dim, latent_dim=latent_dim)
ae_model.load_state_dict(torch.load(r"checkpoints\ae_model.pth", map_location=device))
ae_model.to(device).eval()

# 3) rebuild and attach regressor
in_dim = ae_lib.feats.shape[1]       # 3
out_dim = ae_lib.Z_latent.shape[1]   # r
ae_reg = LatentRegressor(in_dim=in_dim, out_dim=out_dim, hidden_dims=(64, 64))
ae_reg.load_state_dict(torch.load(r"checkpoints\ae_latent_regressor.pth", map_location=device))
ae_reg.to(device).eval()

ae_lib.attach_regressor(ae_reg, device=device)
ae_lib.attach_decoder(ae_model.decoder)

# %%
td3_agent = make_td3_agent()

# %%
env_rl = PfrIpoptEnv(
    params=params,
    N=10,
    K=20,
    L=20.0,
    dt=0.02,
    target_species="B",
    n_zones=5,
    max_iter=500,
    pca_lib=ae_lib,
)

env_base = PfrIpoptEnv(
    params=params,
    N=10,
    K=20,
    L=20.0,
    dt=0.02,
    target_species="B",
    n_zones=5,
    max_iter=500,
    pca_lib=None,
)

stats = run_td3_with_baseline(
    env_rl=env_rl,
    env_base=env_base,
    agent=td3_agent,
    setpoints=setpoints,
    warm_start_steps=100,
    cfg=REWARD_CFG,
    tee=False,
)
# Out:
# Initial setpoint s0=33.11 solved; starting RL stream with baseline...
# [step 100/2999] s=21.10, r=23.6, iters_rl=14, iters_base=23, time_rl=0.163s, time_base=0.274s | w_warm=0.39, w_pca=0.30, mu=1.42e-03, tol=1.3e-06
# [step 200/2999] s=42.47, r=5.8, iters_rl=22, iters_base=25, time_rl=0.278s, time_base=0.274s | w_warm=0.66, w_pca=0.09, mu=6.77e-02, tol=1.0e-08
# [step 300/2999] s=21.81, r=-26.0, iters_rl=25, iters_base=18, time_rl=0.279s, time_base=0.173s | w_warm=0.67, w_pca=0.09, mu=6.96e-02, tol=1.0e-08
# [step 400/2999] s=23.61, r=38.1, iters_rl=17, iters_base=47, time_rl=0.182s, time_base=0.478s | w_warm=0.66, w_pca=0.10, mu=1.04e-04, tol=7.5e-07
# [step 500/2999] s=44.44, r=42.0, iters_rl=9, iters_base=32, time_rl=0.150s, time_base=0.378s | w_warm=0.09, w_pca=0.67, mu=1.00e-04, tol=1.0e-04
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.19\x3a Maximum Number of Iterations
#       Exceeded.
# [PFR ENV] IPOPT failed or returned non-optimal status at s=39.44
# [step 600/2999] s=25.91, r=26.2, iters_rl=8, iters_base=16, time_rl=0.141s, time_base=0.161s | w_warm=0.10, w_pca=0.66, mu=1.00e-04, tol=3.5e-05
# [step 700/2999] s=38.64, r=42.2, iters_rl=8, iters_base=30, time_rl=0.125s, time_base=0.277s | w_warm=0.09, w_pca=0.67, mu=1.28e-04, tol=1.0e-04
# [step 800/2999] s=44.75, r=38.0, iters_rl=10, iters_base=30, time_rl=0.149s, time_base=0.280s | w_warm=0.11, w_pca=0.61, mu=1.56e-04, tol=4.5e-05
# [step 900/2999] s=27.28, r=18.3, iters_rl=9, iters_base=14, time_rl=0.147s, time_base=0.153s | w_warm=0.44, w_pca=0.40, mu=1.00e-04, tol=1.0e-04
# [step 1000/2999] s=26.48, r=42.8, iters_rl=9, iters_base=33, time_rl=0.135s, time_base=0.377s | w_warm=0.45, w_pca=0.38, mu=1.00e-04, tol=2.2e-05
# [step 1100/2999] s=22.02, r=42.0, iters_rl=9, iters_base=31, time_rl=0.130s, time_base=0.376s | w_warm=0.41, w_pca=0.43, mu=1.00e-04, tol=1.0e-04
# [step 1200/2999] s=46.54, r=23.0, iters_rl=21, iters_base=39, time_rl=0.279s, time_base=0.278s | w_warm=0.41, w_pca=0.43, mu=1.00e-04, tol=1.0e-04
# [step 1300/2999] s=21.11, r=33.0, iters_rl=19, iters_base=45, time_rl=0.278s, time_base=0.476s | w_warm=0.41, w_pca=0.43, mu=1.00e-04, tol=1.0e-04
# [step 1400/2999] s=25.85, r=40.8, iters_rl=12, iters_base=40, time_rl=0.158s, time_base=0.376s | w_warm=0.42, w_pca=0.42, mu=1.71e-04, tol=1.0e-04
# [step 1500/2999] s=38.17, r=33.6, iters_rl=18, iters_base=41, time_rl=0.168s, time_base=0.375s | w_warm=0.43, w_pca=0.40, mu=1.20e-04, tol=4.6e-05
# [step 1600/2999] s=26.72, r=39.6, iters_rl=18, iters_base=58, time_rl=0.280s, time_base=0.577s | w_warm=0.42, w_pca=0.42, mu=1.44e-04, tol=1.0e-04
# [step 1700/2999] s=53.80, r=29.5, iters_rl=14, iters_base=28, time_rl=0.153s, time_base=0.276s | w_warm=0.42, w_pca=0.42, mu=2.52e-04, tol=3.7e-05
# [step 1800/2999] s=53.48, r=20.1, iters_rl=28, iters_base=43, time_rl=0.278s, time_base=0.378s | w_warm=0.38, w_pca=0.45, mu=1.42e-04, tol=1.0e-04
# [step 1900/2999] s=39.40, r=33.0, iters_rl=13, iters_base=31, time_rl=0.167s, time_base=0.276s | w_warm=0.35, w_pca=0.48, mu=1.00e-04, tol=1.0e-04
# [step 2000/2999] s=29.16, r=32.8, iters_rl=10, iters_base=23, time_rl=0.149s, time_base=0.274s | w_warm=0.46, w_pca=0.38, mu=2.08e-04, tol=1.0e-04
# [step 2100/2999] s=52.03, r=17.4, iters_rl=24, iters_base=37, time_rl=0.278s, time_base=0.274s | w_warm=0.44, w_pca=0.40, mu=2.02e-04, tol=1.0e-04
# [step 2200/2999] s=54.19, r=12.6, iters_rl=23, iters_base=31, time_rl=0.280s, time_base=0.273s | w_warm=0.44, w_pca=0.38, mu=3.27e-04, tol=1.0e-04
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.19\x3a Maximum Number of Iterations
#       Exceeded.
# [PFR ENV] IPOPT failed or returned non-optimal status at s=31.60
# [step 2300/2999] s=48.09, r=37.3, iters_rl=11, iters_base=31, time_rl=0.137s, time_base=0.275s | w_warm=0.43, w_pca=0.41, mu=1.14e-04, tol=1.0e-04
# [step 2400/2999] s=31.92, r=40.8, iters_rl=11, iters_base=36, time_rl=0.148s, time_base=0.379s | w_warm=0.42, w_pca=0.43, mu=1.00e-04, tol=3.3e-05
# [step 2500/2999] s=48.96, r=14.4, iters_rl=22, iters_base=31, time_rl=0.281s, time_base=0.276s | w_warm=0.40, w_pca=0.43, mu=1.00e-04, tol=7.8e-05
# [step 2600/2999] s=42.03, r=26.7, iters_rl=17, iters_base=31, time_rl=0.161s, time_base=0.275s | w_warm=0.45, w_pca=0.38, mu=1.31e-04, tol=6.6e-05
# [step 2700/2999] s=38.25, r=34.3, iters_rl=11, iters_base=27, time_rl=0.148s, time_base=0.278s | w_warm=0.48, w_pca=0.35, mu=2.92e-04, tol=2.0e-05
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.19\x3a Maximum Number of Iterations
#       Exceeded.
# [PFR ENV] IPOPT failed or returned non-optimal status at s=26.65
# [step 2800/2999] s=47.74, r=41.2, iters_rl=10, iters_base=37, time_rl=0.147s, time_base=0.276s | w_warm=0.42, w_pca=0.42, mu=1.00e-04, tol=8.9e-05
# [step 2900/2999] s=24.48, r=24.2, iters_rl=10, iters_base=18, time_rl=0.136s, time_base=0.170s | w_warm=0.38, w_pca=0.45, mu=1.00e-04, tol=3.4e-05
# [step 2999/2999] s=50.50, r=29.2, iters_rl=16, iters_base=33, time_rl=0.179s, time_base=0.273s | w_warm=0.46, w_pca=0.37, mu=1.00e-04, tol=5.3e-05
#
# Streaming training with baseline finished. Total RL steps = 2999

# %%
# Saving
td3_agent.save("checkpoints", prefix="td3_ae")
# Out:
# Saved checkpoint to: checkpoints\td3_ae_20251202_032516.pkl

# %% [markdown]
# ## Using VAE

# %%
vae_lib = VaeWarmLibrary.load(r"checkpoints\vae_warm_lib.joblib", coarse_env=pca_env)

input_dim = vae_lib.scaler.mean_.shape[0]
latent_dim = vae_lib.Z_mu.shape[1]

vae_model = PrimalsVAE(in_dim=input_dim, latent_dim=latent_dim)
vae_model.load_state_dict(torch.load(r"checkpoints\vae_model.pth", map_location=device))
vae_model.to(device).eval()

in_dim = vae_lib.feats.shape[1]   # 3
out_dim = vae_lib.Z_mu.shape[1]   # latent_dim
vae_reg = LatentRegressor(in_dim=in_dim, out_dim=out_dim, hidden_dims=(64, 64))
vae_reg.load_state_dict(torch.load(r"checkpoints\vae_latent_regressor.pth", map_location=device))
vae_reg.to(device).eval()

vae_lib.attach_regressor(vae_reg, device=device)
vae_lib.attach_decoder(vae_model.decoder)
# Out:
# [VAE LIB] Loaded from checkpoints\vae_warm_lib.joblib, feats shape=(5000, 3), X_recon shape=(5000, 966)

# %%
td3_agent = make_td3_agent()

# %%
env_rl = PfrIpoptEnv(
    params=params,
    N=10,
    K=20,
    L=20.0,
    dt=0.02,
    target_species="B",
    n_zones=5,
    max_iter=500,
    pca_lib=vae_lib,
)

env_base = PfrIpoptEnv(
    params=params,
    N=10,
    K=20,
    L=20.0,
    dt=0.02,
    target_species="B",
    n_zones=5,
    max_iter=500,
    pca_lib=None,
)

stats = run_td3_with_baseline(
    env_rl=env_rl,
    env_base=env_base,
    agent=td3_agent,
    setpoints=setpoints,
    warm_start_steps=100,
    cfg=REWARD_CFG,
    tee=False,
)
# Out:
# Initial setpoint s0=33.11 solved; starting RL stream with baseline...
# [step 100/2999] s=21.10, r=18.7, iters_rl=16, iters_base=23, time_rl=0.180s, time_base=0.276s | w_warm=0.35, w_pca=0.29, mu=4.63e-03, tol=4.6e-07
# [step 200/2999] s=42.47, r=1.9, iters_rl=24, iters_base=25, time_rl=0.278s, time_base=0.275s | w_warm=0.46, w_pca=0.36, mu=2.21e-04, tol=1.4e-07
# [step 300/2999] s=21.81, r=15.3, iters_rl=13, iters_base=18, time_rl=0.149s, time_base=0.174s | w_warm=0.40, w_pca=0.43, mu=1.23e-04, tol=1.0e-08
# [step 400/2999] s=23.61, r=37.1, iters_rl=18, iters_base=47, time_rl=0.179s, time_base=0.476s | w_warm=0.42, w_pca=0.42, mu=3.62e-04, tol=3.4e-08
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.19\x3a Maximum Number of Iterations
#       Exceeded.
# [PFR ENV] IPOPT failed or returned non-optimal status at s=32.28
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.14.19\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.
# [PFR ENV] IPOPT failed or returned non-optimal status at s=24.10
# [step 500/2999] s=44.44, r=29.1, iters_rl=15, iters_base=32, time_rl=0.279s, time_base=0.375s | w_warm=0.42, w_pca=0.39, mu=2.63e-04, tol=2.4e-08
# [step 600/2999] s=25.91, r=6.5, iters_rl=14, iters_base=16, time_rl=0.161s, time_base=0.164s | w_warm=0.38, w_pca=0.42, mu=1.00e-04, tol=1.0e-08
# [step 700/2999] s=38.64, r=21.7, iters_rl=19, iters_base=30, time_rl=0.182s, time_base=0.274s | w_warm=0.40, w_pca=0.44, mu=1.00e-04, tol=5.5e-08
# [step 800/2999] s=44.75, r=25.8, iters_rl=17, iters_base=30, time_rl=0.181s, time_base=0.307s | w_warm=0.42, w_pca=0.42, mu=2.13e-04, tol=1.0e-08
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.19\x3a Maximum Number of Iterations
#       Exceeded.
# [PFR ENV] IPOPT failed or returned non-optimal status at s=27.35
# [step 900/2999] s=27.28, r=14.8, iters_rl=10, iters_base=14, time_rl=0.147s, time_base=0.154s | w_warm=0.42, w_pca=0.43, mu=1.50e-02, tol=1.0e-04
# [step 1000/2999] s=26.48, r=8.5, iters_rl=27, iters_base=33, time_rl=0.377s, time_base=0.375s | w_warm=0.42, w_pca=0.42, mu=8.41e-02, tol=7.6e-05
# [step 1100/2999] s=22.02, r=5.8, iters_rl=27, iters_base=31, time_rl=0.378s, time_base=0.374s | w_warm=0.45, w_pca=0.38, mu=1.00e-01, tol=7.0e-05
# [step 1200/2999] s=46.54, r=16.5, iters_rl=26, iters_base=39, time_rl=0.280s, time_base=0.279s | w_warm=0.09, w_pca=0.66, mu=1.00e-01, tol=1.0e-04
# [step 1300/2999] s=21.11, r=-0.6, iters_rl=45, iters_base=45, time_rl=0.480s, time_base=0.477s | w_warm=0.11, w_pca=0.65, mu=7.26e-02, tol=7.0e-05
# [IPOPT] solve failed with ValueError: Cannot load a SolverResults object with bad status: error
# [PFR ENV] IPOPT failed or returned non-optimal status at s=35.35
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.19\x3a Maximum Number of Iterations
#       Exceeded.
# [PFR ENV] IPOPT failed or returned non-optimal status at s=45.38
# [step 1400/2999] s=25.85, r=25.2, iters_rl=22, iters_base=40, time_rl=0.275s, time_base=0.374s | w_warm=0.12, w_pca=0.63, mu=1.00e-01, tol=8.6e-05
# [step 1500/2999] s=38.17, r=9.1, iters_rl=33, iters_base=41, time_rl=0.383s, time_base=0.376s | w_warm=0.12, w_pca=0.62, mu=1.00e-01, tol=2.6e-05
# [step 1600/2999] s=26.72, r=45.8, iters_rl=13, iters_base=58, time_rl=0.170s, time_base=0.577s | w_warm=0.11, w_pca=0.65, mu=1.86e-04, tol=1.0e-04
# [step 1700/2999] s=53.80, r=29.2, iters_rl=14, iters_base=28, time_rl=0.160s, time_base=0.276s | w_warm=0.09, w_pca=0.67, mu=1.00e-04, tol=4.0e-05
# [step 1800/2999] s=53.48, r=23.5, iters_rl=25, iters_base=43, time_rl=0.281s, time_base=0.377s | w_warm=0.09, w_pca=0.66, mu=1.35e-04, tol=6.1e-05
# [step 1900/2999] s=39.40, r=40.3, iters_rl=9, iters_base=31, time_rl=0.147s, time_base=0.287s | w_warm=0.09, w_pca=0.67, mu=1.00e-04, tol=1.0e-04
# [step 2000/2999] s=29.16, r=30.3, iters_rl=11, iters_base=23, time_rl=0.158s, time_base=0.274s | w_warm=0.10, w_pca=0.66, mu=1.00e-04, tol=1.0e-04
# [step 2100/2999] s=52.03, r=38.5, iters_rl=13, iters_base=37, time_rl=0.149s, time_base=0.378s | w_warm=0.10, w_pca=0.66, mu=1.27e-04, tol=1.0e-04
# [step 2200/2999] s=54.19, r=26.4, iters_rl=17, iters_base=31, time_rl=0.168s, time_base=0.274s | w_warm=0.09, w_pca=0.67, mu=1.62e-04, tol=1.0e-04
# [step 2300/2999] s=48.09, r=30.1, iters_rl=15, iters_base=31, time_rl=0.157s, time_base=0.273s | w_warm=0.12, w_pca=0.61, mu=1.92e-04, tol=3.5e-05
# [step 2400/2999] s=31.92, r=39.4, iters_rl=10, iters_base=36, time_rl=0.251s, time_base=0.372s | w_warm=0.09, w_pca=0.67, mu=1.00e-04, tol=5.4e-05
# [step 2500/2999] s=48.96, r=37.4, iters_rl=11, iters_base=31, time_rl=0.136s, time_base=0.278s | w_warm=0.10, w_pca=0.66, mu=1.00e-04, tol=1.0e-04
# [step 2600/2999] s=42.03, r=32.0, iters_rl=14, iters_base=31, time_rl=0.150s, time_base=0.275s | w_warm=0.10, w_pca=0.63, mu=1.00e-04, tol=1.0e-04
# [step 2700/2999] s=38.25, r=36.1, iters_rl=10, iters_base=27, time_rl=0.148s, time_base=0.276s | w_warm=0.12, w_pca=0.59, mu=1.87e-04, tol=6.7e-05
# [step 2800/2999] s=47.74, r=35.3, iters_rl=14, iters_base=37, time_rl=0.158s, time_base=0.272s | w_warm=0.11, w_pca=0.65, mu=1.00e-04, tol=1.0e-04
# [step 2900/2999] s=24.48, r=23.9, iters_rl=10, iters_base=18, time_rl=0.138s, time_base=0.166s | w_warm=0.14, w_pca=0.53, mu=1.61e-04, tol=1.0e-04
# [step 2999/2999] s=50.50, r=14.7, iters_rl=23, iters_base=33, time_rl=0.288s, time_base=0.275s | w_warm=0.12, w_pca=0.59, mu=1.00e-04, tol=3.9e-05
#
# Streaming training with baseline finished. Total RL steps = 2999

# %%
# Saving
td3_agent.save("checkpoints", prefix="td3_vae")
# Out:
# Saved checkpoint to: checkpoints\td3_vae_20251202_035341.pkl
